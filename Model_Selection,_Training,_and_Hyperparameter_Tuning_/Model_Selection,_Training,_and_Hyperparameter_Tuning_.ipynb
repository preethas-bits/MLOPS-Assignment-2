# %% [markdown]
# # Model Selection, Training, and Hyperparameter Tuning

# %% [markdown]
# ### H2O AutoML
# ###### offers a comprehensive solution for automating the machine learning workflow. By handling model selection, hyperparameter tuning, and feature engineering, it allows users to efficiently build high-performance models with minimal manual intervention. The leaderboard and stacked ensembles further enhance its effectiveness by providing insights into model performance and combining multiple models for better results.

# %%
# !pip install h2o
# Out:
# Requirement already satisfied: h2o in c:\users\preethas\appdata\local\anaconda3\lib\site-packages (3.46.0.5)
# Requirement already satisfied: tabulate in c:\users\preethas\appdata\local\anaconda3\lib\site-packages (from h2o) (0.8.10)
# Requirement already satisfied: requests in c:\users\preethas\appdata\local\anaconda3\lib\site-packages (from h2o) (2.32.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\preethas\appdata\local\anaconda3\lib\site-packages (from requests->h2o) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\preethas\appdata\local\anaconda3\lib\site-packages (from requests->h2o) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\preethas\appdata\local\anaconda3\lib\site-packages (from requests->h2o) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\preethas\appdata\local\anaconda3\lib\site-packages (from requests->h2o) (1.26.14)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\preethas\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\preethas\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\preethas\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\preethas\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\preethas\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\preethas\appdata\local\anaconda3\lib\site-packages)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
from h2o.explanation import explain
# Hide all warnings
warnings.filterwarnings('ignore')

# %%
import h2o
from h2o.automl import H2OAutoML
import pandas as pd

# Initialize H2O cluster
h2o.init()
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# Split the DataFrame into training and test sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)  # 20% for testing

# Save the DataFrames to CSV files
train_df.to_csv('train_data.csv', index=False)
test_df.to_csv('test_data.csv', index=False)

print("Training data saved to 'train_data.csv'")
print("Test data saved to 'test_data.csv'")

h2o_df = h2o.H2OFrame(train_df)

# Split dataset into training and test sets
train, test = h2o_df.split_frame(ratios=[.8])

# Define target and features
target = 'Survived'
features = h2o_df.columns
features.remove(target)

# Train H2O AutoML
aml = H2OAutoML(max_runtime_secs=60, seed=123, max_models=5)  # AutoML will run for 1 hour
aml.train(x=features, y=target, training_frame=train)

# View leaderboard
lb = aml.leaderboard
print("Leaderboard:")
print(lb.head())

# Get the leader model
leader_model = aml.leader

# Print the model ID and type
print("Model ID:", leader_model.model_id)
print("Model Type:", leader_model.algo)

# Get and print the leaderboard
lb = aml.leaderboard



# Get detailed model summary
print("Leader Model Summary:")
print(leader_model.summary())

# Get the best model
best_model = aml.leader

# Make predictions on the test set
predictions = best_model.predict(test)

# Evaluate the best model
performance = best_model.model_performance(test)
print(performance)

# Save the best model
best_model_path = h2o.save_model(model=best_model, path="./best_model", force=True)
print(f"Model saved to: {best_model_path}")
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -------------------------------
# H2O_cluster_uptime:         2 hours 1 min
# H2O_cluster_timezone:       Asia/Kolkata
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.5
# H2O_cluster_version_age:    8 days
# H2O_cluster_name:           H2O_from_python_preethas_vrcy86
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    15.86 Gb
# H2O_cluster_total_cores:    20
# H2O_cluster_allowed_cores:  20
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.9 final
# --------------------------  -------------------------------
# Training data saved to 'train_data.csv'
# Test data saved to 'test_data.csv'
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
#
# 18:26:06.346: AutoML: XGBoost is not available; skipping it.
# 18:26:06.346: _train param, Dropping bad and constant columns: [Name]
# 18:26:06.346: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 18:26:06.452: _train param, Dropping bad and constant columns: [Name]
# 18:26:06.452: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 18:26:06.654: _train param, Dropping bad and constant columns: [Name]
# 18:26:06.654: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 18:26:06.904: _train param, Dropping bad and constant columns: [Name]
# 18:26:06.904: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 18:26:07.16: _train param, Dropping bad and constant columns: [Name]
# 18:26:07.16: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 18:26:07.158: _train param, Dropping unused columns: [Name]
# 18:26:07.158: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 18:26:07.264: _train param, Dropping unused columns: [Name]
# 18:26:07.264: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# Leaderboard:
# model_id                                                     rmse       mse       mae     rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606  0.361039  0.130349  0.266303  0.254895                  0.130349
# GBM_3_AutoML_4_20240906_182606                           0.361231  0.130488  0.267309  0.256254                  0.130488
# StackedEnsemble_AllModels_1_AutoML_4_20240906_182606     0.362785  0.131613  0.271786  0.256012                  0.131613
# DRF_1_AutoML_4_20240906_182606                           0.363351  0.132024  0.260976  0.257378                  0.132024
# GBM_2_AutoML_4_20240906_182606                           0.363798  0.132349  0.264908  0.258295                  0.132349
# GLM_1_AutoML_4_20240906_182606                           0.38443   0.147786  0.296123  0.272241                  0.147786
# GBM_1_AutoML_4_20240906_182606                           0.389296  0.151552  0.317297  0.275377                  0.151552
# [7 rows x 6 columns]
#
# Model ID: StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606
# Model Type: stackedensemble
# Leader Model Summary:
# Model Summary for Stacked Ensemble:
# key                                   value
# ------------------------------------  ----------------
# Stacking strategy                     cross_validation
# Number of base models (used / total)  3/3
# # GBM base models (used / total)      1/1
# # DRF base models (used / total)      1/1
# # GLM base models (used / total)      1/1
# Metalearner algorithm                 GLM
# Metalearner fold assignment scheme    Random
# Metalearner nfolds                    5
# Metalearner fold_column
# Custom metalearner hyperparameters    None
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on test data. **
#
# MSE: 0.1391992173225569
# RMSE: 0.3730941132242064
# MAE: 0.28127159633036775
# RMSLE: 0.2616645355168869
# Mean Residual Deviance: 0.1391992173225569
# R^2: 0.426866555899
# Null degrees of freedom: 153
# Residual degrees of freedom: 150
# Null deviance: 37.787489883223486
# Residual deviance: 21.436679467673766
# AIC: 143.36829854485666
# Model saved to: C:\Users\preethas\MLOPS Assignment 2 Sep 5\best_model\StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 70
#      67 print(f"Model saved to: {best_model_path}")
#      69 # Convert H2O model to SHAP explainer
# ---> 70 explainer = shap.Explainer(best_model, train)
#      71 shap_values = explainer(test)
#      73 # Plot SHAP values
#
# NameError: name 'shap' is not defined

# %% [markdown]
# # Explainable AI using H2O's built-in tools

# %%
# Explain model using H2O's built-in tools
explanations = explain(best_model, test)
print(explanations)
# Out:
# # Residual Analysis
# > Residual Analysis plots the fitted values vs residuals on a test dataset. Ideally, residuals should be randomly distributed. Patterns in this plot can indicate potential problems with the model selection, e.g., using simpler model than necessary, not accounting for heteroscedasticity, autocorrelation, etc. Note that if you see "striped" lines of residuals, that is an artifact of having an integer valued (vs a real valued) response variable.
# # Learning Curve Plot
# > Learning curve plot shows the loss function/metric dependent on number of iterations or trees for tree-based algorithms. This plot can be useful for determining whether the model overfits.
# # Partial Dependence Plots
# > Partial dependence plot (PDP) gives a graphical depiction of the marginal effect of a variable on the response. The effect of a variable is measured in change in the mean response. PDP assumes independence between the feature for which is the PDP computed and the rest.
# # Individual Conditional Expectation
# > An Individual Conditional Expectation (ICE) plot gives a graphical depiction of the marginal effect of a variable on the response. ICE plots are similar to partial dependence plots (PDP); PDP shows the average effect of a feature while ICE plot shows the effect for a single instance. This function will plot the effect for each decile. In contrast to the PDP, ICE plots can provide more insight, especially when there is stronger feature interaction.
# H2OExplanation([('residual_analysis', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x000002D7F5B53AF0>), ('description', <h2o.explanation._explain.Description object at 0x000002D7EE4AC520>), ('plots', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F5BBD570>)]))])), ('learning_curve', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x000002D7EE6D00A0>), ('description', <h2o.explanation._explain.Description object at 0x000002D7F5B6EDA0>), ('plots', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F5FC5B10>)]))])), ('pdp', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x000002D7F5BBD750>), ('description', <h2o.explanation._explain.Description object at 0x000002D7F5EFFEE0>), ('plots', H2OExplanation([('PassengerId', <h2o.plot._plot_result._MObject object at 0x000002D7F6097550>), ('Pclass', <h2o.plot._plot_result._MObject object at 0x000002D7F610BD30>), ('Sex', <h2o.plot._plot_result._MObject object at 0x000002D7F61DD600>), ('Age', <h2o.plot._plot_result._MObject object at 0x000002D7F623F280>), ('SibSp', <h2o.plot._plot_result._MObject object at 0x000002D7F62D3940>), ('Parch', <h2o.plot._plot_result._MObject object at 0x000002D7F638C910>), ('Ticket', <h2o.plot._plot_result._MObject object at 0x000002D7F64370A0>), ('Fare', <h2o.plot._plot_result._MObject object at 0x000002D7F5BBDDB0>), ('Cabin', <h2o.plot._plot_result._MObject object at 0x000002D7F61A2B60>), ('Embarked', <h2o.plot._plot_result._MObject object at 0x000002D7F6B65A80>)]))])), ('ice', H2OExplanation([('header', <h2o.explanation._explain.Header object at 0x000002D7F5B52170>), ('description', <h2o.explanation._explain.Description object at 0x000002D7F6B1B6D0>), ('plots', H2OExplanation([('PassengerId', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F6B39600>)])), ('Pclass', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F6CE2110>)])), ('Sex', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F6EA5270>)])), ('Age', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F6F06860>)])), ('SibSp', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F9C44490>)])), ('Parch', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F9D592D0>)])), ('Ticket', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F9E011B0>)])), ('Fare', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F9F0F610>)])), ('Cabin', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F6DDF250>)])), ('Embarked', H2OExplanation([('StackedEnsemble_BestOfFamily_1_AutoML_4_20240906_182606', <h2o.plot._plot_result._MObject object at 0x000002D7F6DF87F0>)]))]))]))])

# %%
# Load the saved model
loaded_model = h2o.load_model(best_model_path)

# Load new data for prediction
new_data = h2o.import_file('test_data.csv')
print(new_data.head())
# Make predictions with the loaded model
predictions = loaded_model.predict(new_data)

# Convert to pandas DataFrame (if needed)
predictions_df = predictions.as_data_frame()
# Assuming the prediction column is named 'predict'
predictions_df['predicted_class'] = (predictions_df['predict'] >= 0.5).astype(int)
# Show predictions
print(predictions_df.head())
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
#   PassengerId    Survived    Pclass  Name                                               Sex       Age    SibSp    Parch    Ticket     Fare  Cabin    Embarked
#           710           1         3  Moubarek, Master. Halim Gonios ("William George")  male      nan        1        1      2661  15.2458           C
#           440           0         2  Kvillner, Mr. Johan Henrik Johannesson             male       31        0        0       nan  10.5              S
#           841           0         3  Alhomaki, Mr. Ilmari Rudolf                        male       20        0        0       nan   7.925            S
#           721           1         2  Harper, Miss. Annie Jessie "Nina"                  female      6        0        1    248727  33                S
#            40           1         3  Nicola-Yarred, Miss. Jamila                        female     14        1        0      2651  11.2417           C
#           291           1         1  Barber, Miss. Ellen "Nellie"                       female     26        0        0     19877  78.85             S
#           301           1         3  Kelly, Miss. Anna Katherine "Annie Kate"           female    nan        0        0      9234   7.75             Q
#           334           0         3  Vander Planke, Mr. Leo Edmondus                    male       16        2        0    345764  18                S
#           209           1         3  Carr, Miss. Helen "Ellen"                          female     16        0        0    367231   7.75             Q
#           137           1         1  Newsom, Miss. Helen Monypeny                       female     19        0        2     11752  26.2833  D47      S
# [10 rows x 12 columns]
#
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
#     predict  predicted_class
# 0  0.336137                0
# 1  0.182263                0
# 2  0.197637                0
# 3  0.910031                1
# 4  0.514964                1

# %%
# Shutdown the H2O cluster
h2o.shutdown()
